# %%
# Writer Takashi
import math
import numpy as np

#Define
N = 500#半荘数
last_p = float(0.25)

#組み合わせ関数
def combinations_count(n, r):
    return math.factorial(n) // (math.factorial(n - r) * math.factorial(r))

# log(n!)を求める関数
def lnfact(n):
    sum = 0
    for i in np.arange(1, n+1, 1):
        sum += np.log(i)
    return sum

#半荘数Nに対してラスの数nとなる確率
def last_per(N,n):
    return np.exp((N*np.log(last_p) + (N-n)*np.log(4-1) + lnfact(N) - lnfact(N-n) - lnfact(n)))

# %%
import numpy as np
import matplotlib.pyplot as plt

#各種パラメータ設定
N = 100#半荘数
min_per = 0#最低ラスハッシュ率
max_per = 1#最高ラスハッシュ率

x = np.empty(0)
for i in range(int(N*min_per),int(N*max_per)):
    x = np.append(x, last_per(N,i))

y = list(np.arange(N*min_per, N *max_per))

plt.xlabel("last_hash num")
plt.ylabel("Percent")
plt.plot(y,x)

# %%
import numpy as np
import matplotlib.pyplot as plt

#各種パラメータ設定
N = 100#半荘数
min_per = 0#最低ラスハッシュ率
max_per = 1#最高ラスハッシュ率

x = np.empty(0)
for i in range(int(N*min_per),int(N*max_per)):
    x = np.append(x, last_per(N,i))

y = list(np.arange(N*min_per, N *max_per))

plt.xlabel("last_hash num")
plt.ylabel("Percent")
plt.plot(y,x)

# %%
#面積計算
print(len(x))
sum=0
real_per = 0.237#ッシュ率
num = int(N*real_per - N*min_per)
num = 31
for i in range(num):
    sum += x[i]
print(sum)
print(num)
print("last_num : " + str(N*real_per))
# Out:
# 100
# 0.8962127610439935
# 31
# last_num : 23.7
